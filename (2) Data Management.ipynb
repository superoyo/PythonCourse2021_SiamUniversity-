# %% [markdown]
# # (2) Data Management.ipynb

# %% [markdown]
# ## Load Data

# %%
import pandas as pd

data=pd.read_csv('bank-data.csv',sep=';')

# %%
# get current path
import os
os.path.abspath(os.getcwd())
# Out:
# '/Users/anan/Desktop/PythonCourse2021_SiamUniversity-'

# %%
data.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
#ดู Data Type ต่าง ๆ
data.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %%
#select columns use []
data['job']
# Out:
# 0          management
# 1          technician
# 2        entrepreneur
# 3         blue-collar
# 4             unknown
#              ...
# 45206      technician
# 45207         retired
# 45208         retired
# 45209     blue-collar
# 45210    entrepreneur
# Name: job, Length: 45211, dtype: object

# %%
#select multiple columns <- use list in bracket [] 
data[['job','age']]
# Out:
#                 job  age
# 0        management   58
# 1        technician   44
# 2      entrepreneur   33
# 3       blue-collar   47
# 4           unknown   33
# ...             ...  ...
# 45206    technician   51
# 45207       retired   71
# 45208       retired   72
# 45209   blue-collar   57
# 45210  entrepreneur   37
#
# [45211 rows x 2 columns]

# %%
dataFilter3 = data[['education','job','balance']]
dataFilter3
# Out:
#        education           job  balance
# 0       tertiary    management     2143
# 1      secondary    technician       29
# 2      secondary  entrepreneur        2
# 3        unknown   blue-collar     1506
# 4        unknown       unknown        1
# ...          ...           ...      ...
# 45206   tertiary    technician      825
# 45207    primary       retired     1729
# 45208  secondary       retired     5715
# 45209  secondary   blue-collar      668
# 45210  secondary  entrepreneur     2971
#
# [45211 rows x 3 columns]

# %%
#rename columns
# use function rename and pass dictionary to 
data = data.rename(columns={'default':'defaults'})
data
# Out:
#        age           job   marital  education defaults  balance housing loan  \
# 0       58    management   married   tertiary       no     2143     yes   no
# 1       44    technician    single  secondary       no       29     yes   no
# 2       33  entrepreneur   married  secondary       no        2     yes  yes
# 3       47   blue-collar   married    unknown       no     1506     yes   no
# 4       33       unknown    single    unknown       no        1      no   no
# ...    ...           ...       ...        ...      ...      ...     ...  ...
# 45206   51    technician   married   tertiary       no      825      no   no
# 45207   71       retired  divorced    primary       no     1729      no   no
# 45208   72       retired   married  secondary       no     5715      no   no
# 45209   57   blue-collar   married  secondary       no      668      no   no
# 45210   37  entrepreneur   married  secondary       no     2971      no   no
#
# ...

# %%
data.rename(columns={'loan':'loaner','month':'months'})
# Out:
#        age           job   marital  education defaults  balance housing  \
# 0       58    management   married   tertiary       no     2143     yes
# 1       44    technician    single  secondary       no       29     yes
# 2       33  entrepreneur   married  secondary       no        2     yes
# 3       47   blue-collar   married    unknown       no     1506     yes
# 4       33       unknown    single    unknown       no        1      no
# ...    ...           ...       ...        ...      ...      ...     ...
# 45206   51    technician   married   tertiary       no      825      no
# 45207   71       retired  divorced    primary       no     1729      no
# 45208   72       retired   married  secondary       no     5715      no
# 45209   57   blue-collar   married  secondary       no      668      no
# 45210   37  entrepreneur   married  secondary       no     2971      no
#
#       loaner    contact  day months  duration  campaign  pdays  previous  \
# ...

# %%
data[data['age']>50]
# Out:
#        age          job   marital  education defaults  balance housing loan  \
# 0       58   management   married   tertiary       no     2143     yes   no
# 8       58      retired   married    primary       no      121     yes   no
# 12      53   technician   married  secondary       no        6     yes   no
# 13      58   technician   married    unknown       no       71     yes   no
# 14      57     services   married  secondary       no      162     yes   no
# ...    ...          ...       ...        ...      ...      ...     ...  ...
# 45204   73      retired   married  secondary       no     2850      no   no
# 45206   51   technician   married   tertiary       no      825      no   no
# 45207   71      retired  divorced    primary       no     1729      no   no
# 45208   72      retired   married  secondary       no     5715      no   no
# 45209   57  blue-collar   married  secondary       no      668      no   no
#
# ...

# %%
data4 = data[data['age']<30]
data4[['age','job','marital']]
# Out:
#        age            job  marital
# 6       28     management   single
# 11      29         admin.   single
# 20      28    blue-collar  married
# 23      25       services  married
# 36      25    blue-collar  married
# ...    ...            ...      ...
# 45192   29     management   single
# 45193   28  self-employed   single
# 45196   25        student   single
# 45203   23        student   single
# 45205   25     technician   single
#
# [5273 rows x 3 columns]

# %%
data[data['age']<30][['age','job','marital']]
# Out:
#        age            job  marital
# 6       28     management   single
# 11      29         admin.   single
# 20      28    blue-collar  married
# 23      25       services  married
# 36      25    blue-collar  married
# ...    ...            ...      ...
# 45192   29     management   single
# 45193   28  self-employed   single
# 45196   25        student   single
# 45203   23        student   single
# 45205   25     technician   single
#
# [5273 rows x 3 columns]

# %%
data[data['job']=='management'].head()
# Out:
#     age         job  marital education defaults  balance housing loan  \
# 0    58  management  married  tertiary       no     2143     yes   no
# 5    35  management  married  tertiary       no      231     yes   no
# 6    28  management   single  tertiary       no      447     yes  yes
# 21   56  management  married  tertiary       no      779     yes   no
# 26   39  management   single  tertiary       no      255     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0   unknown    5   may       261         1     -1         0  unknown  no
# 5   unknown    5   may       139         1     -1         0  unknown  no
# 6   unknown    5   may       217         1     -1         0  unknown  no
# 21  unknown    5   may       164         1     -1         0  unknown  no
# 26  unknown    5   may       296         1     -1         0  unknown  no

# %%
data[data['age']<30].head()
# Out:
#     age          job  marital  education defaults  balance housing loan  \
# 6    28   management   single   tertiary       no      447     yes  yes
# 11   29       admin.   single  secondary       no      390     yes   no
# 20   28  blue-collar  married  secondary       no      723     yes  yes
# 23   25     services  married  secondary       no       50     yes   no
# 36   25  blue-collar  married  secondary       no       -7     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 6   unknown    5   may       217         1     -1         0  unknown  no
# 11  unknown    5   may       137         1     -1         0  unknown  no
# 20  unknown    5   may       262         1     -1         0  unknown  no
# 23  unknown    5   may       342         1     -1         0  unknown  no
# 36  unknown    5   may       365         1     -1         0  unknown  no

# %%
#direction 1
dataM30 = data[(data['job']=='management')&(data['age']<30)]
dataM30 = dataM30[['age','job','marital','balance']]

#direction 2
dataM30_2 = data[(data['job']=='management')&(data['age']<30)][['age','job','marital','balance']]
dataM30_2

#direction3
dataM30_3 = data[data['age']<30]
dataM30_3 = dataM30_3[dataM30_3['job']=='management']
dataM30_3 = dataM30_3[['age','job','marital','balance']]
dataM30_3
# Out:
#        age         job  marital  balance
# 6       28  management   single      447
# 49      29  management   single        0
# 523     29  management   single        0
# 938     27  management   single      134
# 950     29  management  married      147
# ...    ...         ...      ...      ...
# 45041   29  management   single      600
# 45046   27  management   single      107
# 45113   26  management   single      222
# 45188   29  management   single      703
# 45192   29  management   single      765
#
# [758 rows x 4 columns]

# %%
#เติม column
dataM30['PrepBy']='Anan'
dataM30
# Out:
#        age         job  marital  balance PrepBy
# 6       28  management   single      447   Anan
# 49      29  management   single        0   Anan
# 523     29  management   single        0   Anan
# 938     27  management   single      134   Anan
# 950     29  management  married      147   Anan
# ...    ...         ...      ...      ...    ...
# 45041   29  management   single      600   Anan
# 45046   27  management   single      107   Anan
# 45113   26  management   single      222   Anan
# 45188   29  management   single      703   Anan
# 45192   29  management   single      765   Anan
#
# [758 rows x 5 columns]

# %%
dataM30.to_csv('bank-data-M30.csv')

# %%
import pandas as pd
data=pd.read_csv('mtcars.csv')

# %%
data.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
data.head()
# Out:
#           Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
data['Unnamed: 0']
# Out:
# 0               Mazda RX4
# 1           Mazda RX4 Wag
# 2              Datsun 710
# 3          Hornet 4 Drive
# 4       Hornet Sportabout
# 5                 Valiant
# 6              Duster 360
# 7               Merc 240D
# 8                Merc 230
# 9                Merc 280
# 10              Merc 280C
# 11             Merc 450SE
# 12             Merc 450SL
# 13            Merc 450SLC
# 14     Cadillac Fleetwood
# 15    Lincoln Continental
# 16      Chrysler Imperial
# 17               Fiat 128
# 18            Honda Civic
# 19         Toyota Corolla
# 20          Toyota Corona
# 21       Dodge Challenger
# 22            AMC Javelin
# 23             Camaro Z28
# 24       Pontiac Firebird
# 25              Fiat X1-9
# 26          Porsche 914-2
# 27           Lotus Europa
# 28         Ford Pantera L
# 29           Ferrari Dino
# 30          Maserati Bora
# 31             Volvo 142E
# Name: Unnamed: 0, dtype: object

# %%
data=data.rename(columns={'Unnamed: 0':'model'})
data
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
data[['model','mpg']]
# Out:
#                   model   mpg
# 0             Mazda RX4  21.0
# 1         Mazda RX4 Wag  21.0
# 2            Datsun 710  22.8
# 3        Hornet 4 Drive  21.4
# 4     Hornet Sportabout  18.7
# 5               Valiant  18.1
# 6            Duster 360  14.3
# 7             Merc 240D  24.4
# 8              Merc 230  22.8
# 9              Merc 280  19.2
# 10            Merc 280C  17.8
# 11           Merc 450SE  16.4
# 12           Merc 450SL  17.3
# 13          Merc 450SLC  15.2
# 14   Cadillac Fleetwood  10.4
# 15  Lincoln Continental  10.4
# 16    Chrysler Imperial  14.7
# 17             Fiat 128  32.4
# 18          Honda Civic  30.4
# 19       Toyota Corolla  33.9
# 20        Toyota Corona  21.5
# 21     Dodge Challenger  15.5
# 22          AMC Javelin  15.2
# 23           Camaro Z28  13.3
# 24     Pontiac Firebird  19.2
# 25            Fiat X1-9  27.3
# 26        Porsche 914-2  26.0
# 27         Lotus Europa  30.4
# 28       Ford Pantera L  15.8
# 29         Ferrari Dino  19.7
# ...

# %%
data['model'].count()
# Out:
# 32

# %%
data.groupby('model').count().shape
# Out:
# (32, 11)

# %%
bank=pd.read_csv('bank-data.csv',sep=';')
bank
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
bank.groupby('job').sum()
# Out:
#                   age   balance     day  duration  campaign   pdays  previous
# job
# admin.         203168   5873423   80483   1276703     13317  247479      3473
# blue-collar    389709  10499141  150287   2558558     27415  428534      4916
# entrepreneur    62738   2262426   23349    381132      4163   48307       711
# housemaid       57555   1726570   19843    304823      3498   26667       461
# management     382572  16680288  152408   2402292     27091  365698      6318
# retired        139523   4492263   34955    650586      5313   84773      1446
# self-employed   63925   2602146   25308    423420      4505   54866       871
# services       160927   4141904   64950   1077210     11292  174448      2082
# student         24897   1302001   13974    231364      2157   53505       894
# technician     298673   9516246  124656   1921319     22083  282571      4365
# unemployed      53373   1982835   20194    375972      3169   44493       608
# ...

# %%
bank.groupby('job').count()
# Out:
#                 age  marital  education  default  balance  housing  loan  \
# job
# admin.         5171     5171       5171     5171     5171     5171  5171
# blue-collar    9732     9732       9732     9732     9732     9732  9732
# entrepreneur   1487     1487       1487     1487     1487     1487  1487
# housemaid      1240     1240       1240     1240     1240     1240  1240
# management     9458     9458       9458     9458     9458     9458  9458
# retired        2264     2264       2264     2264     2264     2264  2264
# self-employed  1579     1579       1579     1579     1579     1579  1579
# services       4154     4154       4154     4154     4154     4154  4154
# student         938      938        938      938      938      938   938
# technician     7597     7597       7597     7597     7597     7597  7597
# unemployed     1303     1303       1303     1303     1303     1303  1303
# unknown         288      288        288      288      288      288   288
#
# ...

# %%
bank.groupby('job').size()
# Out:
# job
# admin.           5171
# blue-collar      9732
# entrepreneur     1487
# housemaid        1240
# management       9458
# retired          2264
# self-employed    1579
# services         4154
# student           938
# technician       7597
# unemployed       1303
# unknown           288
# dtype: int64

# %%
bank.shape
# Out:
# (45211, 17)

# %%
bank2=bank[bank['job']=='management'][['age','job']]
